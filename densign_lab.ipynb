# %%
import pandas as pd

# %%
df_list = []
file_path = "data_sales/densign/apr.2021.xlsx"
df = pd.read_excel(file_path)
df
# Out:
#                                           Densign Lab Unnamed: 1 Unnamed: 2  \
# 0                                 2023-11-28 13:58:00        NaN        NaN
# 1     Product Activity Report (01 Apr 21 - 30 Apr 21)        NaN        NaN
# 2                                           Filters:         NaN        NaN
# 3                                      Customers: All        NaN        NaN
# 4                                        Classes: All        NaN        NaN
# ...                                               ...        ...        ...
# 1779                                              NaN        NaN        NaN
# 1780                                           Totals        NaN        NaN
# 1781                                              NaN        NaN        NaN
# 1782                   is a trademark of Evident Inc.        NaN        NaN
# 1783                   is a trademark of Evident Inc.        NaN        NaN
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 1779  Alloy arg43       9.13        NaN        NaN        NaN        NaN
# 1780          NaN    4319.69        418       9.68  304458.04        100
# 1781          NaN        NaN        NaN        NaN        NaN        NaN
# 1782          NaN        NaN        NaN        NaN        NaN        NaN
# 1783          NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN
# ...         ...         ...         ...         ...
# 1779     319.55           0           0      319.55
# 1780    2961.44         NaN           0   307419.48
# 1781        NaN         NaN         NaN         NaN
# 1782        NaN         NaN         NaN         NaN
# 1783        NaN         NaN         NaN         NaN
#
# [1784 rows x 13 columns]

# %%
import dateutil.parser as dparser

# %%
date_str = df["Densign Lab"].values[1]
first_date = dparser.parse(date_str.split("-")[0], fuzzy=True)

# %%
date_str
# Out:
# 'Product Activity Report (01 Apr 21 - 30 Apr 21)'

# %%
date_str.split("-")[0]
# Out:
# 'Product Activity Report (01 Apr 21 '

# %%
first_date
# Out:
# datetime.datetime(2021, 4, 1, 0, 0)

# %%
df_new = df.iloc[5:, :]
df_new
# Out:
#                          Densign Lab    Unnamed: 1            Unnamed: 2  \
# 5                      Customer Code  Dentist Name         Practice Name
# 6                               1014     Alex Wood  WOODFORD DENTAL CARE
# 7                                NaN           NaN                   NaN
# 8                                NaN           NaN                   NaN
# 9                                NaN           NaN                   NaN
# ...                              ...           ...                   ...
# 1779                             NaN           NaN                   NaN
# 1780                          Totals           NaN                   NaN
# 1781                             NaN           NaN                   NaN
# 1782  is a trademark of Evident Inc.           NaN                   NaN
# 1783  is a trademark of Evident Inc.           NaN                   NaN
#
#                           Unnamed: 3      Unnamed: 4     Unnamed: 5  \
# 5                               Item  Product Pieces  Remake Pieces
# 6                                NaN               5              2
# 7           Lithium disilicate Crown               1            NaN
# 8     Lithium disilicate Inlay/Onlay               1            NaN
# 9                     Zirconia Crown               3              2
# ...                              ...             ...            ...
# 1779                     Alloy arg43            9.13            NaN
# 1780                             NaN         4319.69            418
# 1781                             NaN             NaN            NaN
# 1782                             NaN             NaN            NaN
# 1783                             NaN             NaN            NaN
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 5             %    Revenue          %      Alloy  COGS Alloy         Tax
# 6            40        430       0.14        NaN         NaN           0
# 7           NaN        105       0.03        NaN         NaN           0
# 8           NaN        105       0.03        NaN         NaN           0
# 9         66.67        220       0.07        NaN         NaN           0
# ...         ...        ...        ...        ...         ...         ...
# 1779        NaN        NaN        NaN     319.55           0           0
# 1780       9.68  304458.04        100    2961.44         NaN           0
# 1781        NaN        NaN        NaN        NaN         NaN         NaN
# 1782        NaN        NaN        NaN        NaN         NaN         NaN
# 1783        NaN        NaN        NaN        NaN         NaN         NaN
#
#      Unnamed: 12
# 5          Total
# 6            430
# 7            105
# 8            105
# 9            220
# ...          ...
# 1779      319.55
# 1780   307419.48
# 1781         NaN
# 1782         NaN
# 1783         NaN
#
# [1779 rows x 13 columns]

# %%
df_new.columns = df_new.iloc[0, :]
df_new
# Out:
# 5                      Customer Code  Dentist Name         Practice Name  \
# 5                      Customer Code  Dentist Name         Practice Name
# 6                               1014     Alex Wood  WOODFORD DENTAL CARE
# 7                                NaN           NaN                   NaN
# 8                                NaN           NaN                   NaN
# 9                                NaN           NaN                   NaN
# ...                              ...           ...                   ...
# 1779                             NaN           NaN                   NaN
# 1780                          Totals           NaN                   NaN
# 1781                             NaN           NaN                   NaN
# 1782  is a trademark of Evident Inc.           NaN                   NaN
# 1783  is a trademark of Evident Inc.           NaN                   NaN
#
# 5                               Item  Product Pieces  Remake Pieces      %  \
# 5                               Item  Product Pieces  Remake Pieces      %
# 6                                NaN               5              2     40
# 7           Lithium disilicate Crown               1            NaN    NaN
# 8     Lithium disilicate Inlay/Onlay               1            NaN    NaN
# 9                     Zirconia Crown               3              2  66.67
# ...                              ...             ...            ...    ...
# 1779                     Alloy arg43            9.13            NaN    NaN
# 1780                             NaN         4319.69            418   9.68
# 1781                             NaN             NaN            NaN    NaN
# 1782                             NaN             NaN            NaN    NaN
# 1783                             NaN             NaN            NaN    NaN
#
# 5       Revenue     %    Alloy  COGS Alloy  Tax      Total
# 5       Revenue     %    Alloy  COGS Alloy  Tax      Total
# 6           430  0.14      NaN         NaN    0        430
# 7           105  0.03      NaN         NaN    0        105
# 8           105  0.03      NaN         NaN    0        105
# 9           220  0.07      NaN         NaN    0        220
# ...         ...   ...      ...         ...  ...        ...
# 1779        NaN   NaN   319.55           0    0     319.55
# 1780  304458.04   100  2961.44         NaN    0  307419.48
# 1781        NaN   NaN      NaN         NaN  NaN        NaN
# 1782        NaN   NaN      NaN         NaN  NaN        NaN
# 1783        NaN   NaN      NaN         NaN  NaN        NaN
#
# [1779 rows x 13 columns]
