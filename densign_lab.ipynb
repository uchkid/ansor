# %%
import pandas as pd

# %%
df_list = []
file_path = "data_sales/densign/apr.2021.xlsx"
df = pd.read_excel(file_path)
df

# %%
import dateutil.parser as dparser

# %%
date_str = df["Densign Lab"].values[1]
first_date = dparser.parse(date_str.split("-")[0], fuzzy=True)

# %%
date_str

# %%
date_str.split("-")[0]

# %%
first_date

# %%
df_new = df.iloc[5:, :]
df_new

# %%
df_new.columns = df_new.iloc[0, :]
df_new

# %%
ashford_2023 = pd.read_excel("data\sales_ashford\Ashford\Ashford 2023 Labtrac Data.xlsx")
ashford_2023
# Out:
#            DR ID                  DOCTOR NAME  \
# 0            RUP                  RUP BHAMBRA
# 1            RUP                  RUP BHAMBRA
# 2            RUP                  RUP BHAMBRA
# 3             DW       DIAMOND WHITE ALIGNERS
# 4             DW       DIAMOND WHITE ALIGNERS
# ...          ...                          ...
# 289258    SWAN/T               THEO SWANEPOEL
# 289259   PALLETT              GIULIO PELLETTI
# 289260  CEN(ALS)     CENTRAL DENTAL LAB (ALS)
# 289261  BCC(ALS)  BRISTOL CROWN COMPANY (ALS)
# 289262  STDIRECT        STRAIGHT TEETH DIRECT
#
#                                       PRACTICE CASE NUMBER         STATUS  \
# 0                   LOUISE HUNTER & ASSOCIATES  CN558486:1  Case Invoiced
# 1                   LOUISE HUNTER & ASSOCIATES  CN558486:1  Case Invoiced
# 2                   LOUISE HUNTER & ASSOCIATES  CN558486:1  Case Invoiced
# 3                               DIAMOND WHITES  CN561412:3  Case Invoiced
# 4                               DIAMOND WHITES  CN561412:3  Case Invoiced
# ...                                        ...         ...            ...
# 289258        WEST STREET ORTHODONTIC PRACTICE  CN679613:1  Case Invoiced
# 289259        WEST STREET ORTHODONTIC PRACTICE  CN679615:1  Case Invoiced
# 289260  CENTRAL DENTAL LABORATORY KEMPSTON LTD  CN679650:1  Case Invoiced
# 289261           THE BRISTOL CROWN COMPANY LTD  CN679651:1  Case Invoiced
# 289262                   STRAIGHT TEETH DIRECT  CN679679:1           Live
#
#           DATE IN   DUE DATE        INVOICED DATE PRODUCT ID  \
# 0      2022-08-26 2023-01-17  2023-01-17 00:00:00       7000
# 1      2022-08-26 2023-01-17  2023-01-17 00:00:00       7007
# 2      2022-08-26 2023-01-17  2023-01-17 00:00:00       6040
# 3      2022-09-28 2023-03-01  2023-03-01 00:00:00       6030
# 4      2022-09-28 2023-03-01  2023-03-01 00:00:00       7007
# ...           ...        ...                  ...        ...
# 289258 2023-11-29 2023-11-29  2023-11-29 00:00:00       7090
# 289259 2023-11-29 2023-11-29  2023-11-29 00:00:00       7090
# 289260 2023-11-29 2023-11-29  2023-11-29 00:00:00        870
# 289261 2023-11-29 2023-11-29  2023-11-29 00:00:00        870
# 289262 2023-11-29 2023-11-29           30/12/1899       1010
#
#                                         PRODUCT DESC  UNIT    PRICE
# 0       DIGITAL PRINT MODEL (WITH APLIANCE ORDER) DS   4.0    25.00
# 1                           UPPER DIGITAL ALIGNER DS   4.0    79.00
# 2                                 SINGLE POST CHARGE   1.0     6.00
# 3                                     COURIER CHARGE   1.0    13.00
# 4                           UPPER DIGITAL ALIGNER DS  16.0   144.00
# ...                                              ...   ...      ...
# 289258                    PARSCORED MODELS (PER SET)   2.0    19.00
# 289259                    PARSCORED MODELS (PER SET)   2.0    19.00
# 289260                             4L KEYSTONE RESIN   3.0   662.40
# 289261                             4L KEYSTONE RESIN   5.0  1104.00
# 289262                     DIGITAL SCAN OF DENTITION   1.0     9.44
#
# [289263 rows x 12 columns]
