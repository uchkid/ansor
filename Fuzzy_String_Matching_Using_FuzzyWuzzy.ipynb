# %%
# Install the FuzzyWuzzy and Levenshtein library
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 8.8 MB/s eta 0:00:00
# ...

# %%
from fuzzywuzzy import fuzz

# Example article titles
wos_title = "SYNTHESIS AND ELECTROCHEMISTRY OF DIALKYLOSMIUM-(IV) AND DIALKYLOSMIUM-(V) PORPHYRINS - CRYSTAL-STRUCTURE OF [OS(TTP)(CH(2)SIME(3))(2)] [H(2)TTP=5,10,15,20-TETRA(P-TOLYL)PORPHYRIN]"
scopus_title = "Synthesis and electrochemistry of dialkylosmium-(IV) and -(V) porphyrins. Crystal structure of [Os(ttp)(CH2SiMe3)2] [H2ttp = 5,10,15,20-tetra(p-tolyl)porphyrin]"

# Calculate similarity score
similarity_score = fuzz.WRatio(wos_title, scopus_title)

# Print the similarity score
print("Similarity score: ", similarity_score)
# Out:
# Similarity score:  93

# %%
from fuzzywuzzy import process

wos_list = [
    "Synthesis and reactivity of ruthenium(II) complex with an ortho-metalated bis(diphenylthiophosphoryl)imide",
    "Synthesis, Structure, and Reductive Elimination of Cationic Monoarylpalladium(IV) Complexes Supported by a Tripodal Oxygen Ligand",
    "SYNTHESIS AND ELECTROCHEMISTRY OF DIALKYLOSMIUM-(IV) AND DIALKYLOSMIUM-(V) PORPHYRINS - CRYSTAL-STRUCTURE OF [OS(TTP)(CH(2)SIME(3))(2)] [H(2)TTP=5,10,15,20-TETRA(P-TOLYL)PORPHYRIN]",
]

process.extractOne("Synthesis and electrochemistry of dialkylosmium-(IV) and -(V) porphyrins. Crystal structure of [Os(ttp)(CH2SiMe3)2] [H2ttp = 5,10,15,20-tetra(p-tolyl)porphyrin]", wos_list)
# Out:
# ('SYNTHESIS AND ELECTROCHEMISTRY OF DIALKYLOSMIUM-(IV) AND DIALKYLOSMIUM-(V) PORPHYRINS - CRYSTAL-STRUCTURE OF [OS(TTP)(CH(2)SIME(3))(2)] [H(2)TTP=5,10,15,20-TETRA(P-TOLYL)PORPHYRIN]',
#  93)

# %%
from fuzzywuzzy import process
import pandas as pd

scopus_list = [
    "data-sales-A Plus-APlus_ALS_Extract_01012021_31032023.csv",
"data-sales-A Plus-converted_file_excel_to_csv-APlus Extract 2024 01 11.xlsx_Sheet2.csv",
"data-sales-Aesthetic World-Aesthetic Extract 2023 12 20.csv",
"data-sales-Aesthetic World-Aesthetic Extract 2024 01 11.csv",
"data-sales-Aesthetic World-AestheticWorld_ALS_Extract_01012023_31032023.csv",
"data-sales-Burke Orthodontics-Generic - Product Sales by Customer Monthly 2.csv",
"data-sales-Burke Orthodontics-Generic - Product Sales by Customer Monthly Burke Ortho.csv",
"data-sales-Burke Orthodontics-Generic - Product Sales by Customer Monthly joe.csv",
"data-sales-Cardiff Orthodontics-Cardiff Ortho Extract 2023 12 20.csv",
"data-sales-Cardiff Orthodontics-Cardiff Ortho Extract 2024 01 11.csv",
"data-sales-Cardiff Orthodontics-CardiffOrtho_ALS_Extract_SQLDatabase_01012021_31032023.csv",
"data-sales-Casterbridge-Casterbridge Extract 2023 12 20.csv",
"data-sales-Casterbridge-Casterbridge Extract 2024 01 11.csv",
"data-sales-Casterbridge-Casterbridge_ALS_Extract_01012021_31032023.csv",
"data-sales-CBC Dental-Generic - Product Sales by Customer Monthly CBC 2.csv",
"data-sales-CBC Dental-Generic - Product Sales by Customer Monthly.csv",
"data-sales-CBC Dental-TOPUP - Generic - Product Sales by Customer Monthly.csv",
"data-sales-Central Dental Laboratory-CentralDental_ALS_Extract_01012021_31032023.csv",
"data-sales-Central Dental Laboratory-converted_file_excel_to_csv-CentralDental Extract 2024 01 11.xlsx_Sheet1.csv",
"data-sales-Dent8-NEW Generic - Product Sales by Customer Monthly.csv",
"data-sales-Dent8-TOPUP - Generic - Product Sales by Customer Monthlynovdec.csv",
"data-sales-Dent8-converted_file_excel_to_csv-Generic - Product Sales by Customer Monthly Dent8.xlsx_in.csv",
"data-sales-Dental Excellence-DE 1.121-31.10.23  Generic - Product Sales by Customer Monthly.csv",
"data-sales-Dental Excellence-DE Jan24 to April24 Generic - Product Sales by Customer Monthly.csv",
"data-sales-Dental Excellence-TOPUP - DE 1.11.23 - 31.12.23  Product Sales by Customer Monthly.csv",
"data-sales-European Dental Laboratory-Generic - Product Sales by Customer Monthly _European Dental.csv",
"data-sales-European Dental Laboratory-NEW Generic - Product Sales by Customer Monthly ALS.csv",
"data-sales-European Dental Laboratory-TOPUP - Generic - Product Sales by Customer Monthly.csv",
"data-sales-George House-Generic - Product Sales by Customer Monthly (2) George House.csv",
"data-sales-George House-NEW Generic - Product Sales by Customer Monthly.csv",
"data-sales-Innovate-Generic - Product Sales by Customer Monthly.csv",
"data-sales-Innovate-NEW Generic - Product Sales by Customer Monthly.csv",
"data-sales-Innovate-TOPUP - Generic - Product Sales by Customer Monthly.csv",
"data-sales-IW Dental-NEW Generic - Product Sales by Customer Monthly.csv",
"data-sales-IW Dental-TOPUP - Generic - Product Sales by Customer Monthly.csv",
"data-sales-Leca-converted_file_excel_to_csv-Kenny 011123 to 311223.xlsx_SageReportData1.csv",
"data-sales-Leca-converted_file_excel_to_csv-Leca 2021-2023.xlsx_Sheet1.csv",
"data-sales-Leca-converted_file_excel_to_csv-Leca Sales Analysis 010124 to 300424 for Kenny.xlsx_Sheet1.csv",
"data-sales-Lodge-Lodge_ALS_Extract_01012021_31032023.csv",
"data-sales-Lodge-converted_file_excel_to_csv-Lodge Extract 2024 01 11.xlsx_Sheet2.csv",
"data-sales-Oakview Restorations-Generic - Product Sales by Customer Monthly 011123 to 301123.csv",
"data-sales-Oakview Restorations-NEW Generic - Product Sales by Customer Monthly.csv",
"data-sales-Oakview Restorations-Oakview 010124 to 300424 - Product Sales by Customer Monthly.csv",
"data-sales-Passion Dental Design-Generic - Product Sales by Customer Monthly Jan 21 to Oct 23.csv",
"data-sales-Passion Dental Design-Generic - Product Sales by Customer Monthly Nov to Dec 23.csv",
"data-sales-Passion Dental Design-Jan-April24Productsalescustomermonthly Passion.csv",
"data-sales-Precedental-Precedental Extract 2024 01 11.csv",
"data-sales-Precedental-Precedental_ALS_Extract_01012021_31032023.csv",
"data-sales-Romak Denture Centre-Romak Extract 2024 01 11.csv",
"data-sales-Romak Denture Centre-Romak_ALS_Extract_01012021_31032023.csv",
"data-sales-Woodford-Woodford Extract 23 12 22.csv",
"data-sales-Woodford-Woodford_ALS_Extract_01012021_31032023_v2.csv",
"data-sales-Woodford-converted_file_excel_to_csv-Woodford Extract 2024 01 11.xlsx_Woodford_ALS_Export.csv",

]

wos_list = [
    "APlus",
    "Aesthetic World",
    "Burke Orthodontics",
    "Cardiff Orthodontics",
    "Casterbridge",
    "CBC Dental",
    "Central Dental Laboratory",
    "Dent8",
    "Dental Excellence",
    "European Dental Laboratory",
    "George House",
    "Innovate",
    "IW Dental",
    "Leca",
    "Lodge",
    "Oakview Restorations",
    "Passion Dental Design",
    "Precedental",
    "Romak Denture Centre",
    "Woodford",
]

matches = []

for scopus_title in scopus_list:
    match = process.extractOne(scopus_title, wos_list)
    matches.append((scopus_title, match[0], match[1]))

# Create a DataFrame from the fuzzy matching results
data = {'Scopus Title': [match[0] for match in matches],
        'WoS Title': [match[1] for match in matches],
        'Score': [match[2] for match in matches]}

df = pd.DataFrame(data)

# Print the DataFrame
df
# Out:
#                                          Scopus Title  \
# 0   data-sales-A Plus-APlus_ALS_Extract_01012021_3...
# 1   data-sales-A Plus-converted_file_excel_to_csv-...
# 2   data-sales-Aesthetic World-Aesthetic Extract 2...
# 3   data-sales-Aesthetic World-Aesthetic Extract 2...
# 4   data-sales-Aesthetic World-AestheticWorld_ALS_...
# 5   data-sales-Burke Orthodontics-Generic - Produc...
# 6   data-sales-Burke Orthodontics-Generic - Produc...
# 7   data-sales-Burke Orthodontics-Generic - Produc...
# 8   data-sales-Cardiff Orthodontics-Cardiff Ortho ...
# 9   data-sales-Cardiff Orthodontics-Cardiff Ortho ...
# 10  data-sales-Cardiff Orthodontics-CardiffOrtho_A...
# 11  data-sales-Casterbridge-Casterbridge Extract 2...
# 12  data-sales-Casterbridge-Casterbridge Extract 2...
# 13  data-sales-Casterbridge-Casterbridge_ALS_Extra...
# 14  data-sales-CBC Dental-Generic - Product Sales ...
# 15  data-sales-CBC Dental-Generic - Product Sales ...
# ...

# %%
from fuzzywuzzy import process
import pandas as pd

wos_list = [
    "Synthesis and reactivity of ruthenium(II) complex with an ortho-metalated bis(diphenylthiophosphoryl)imide",
    "Synthesis, Structure, and Reductive Elimination of Cationic Monoarylpalladium(IV) Complexes Supported by a Tripodal Oxygen Ligand",
    "SYNTHESIS AND ELECTROCHEMISTRY OF DIALKYLOSMIUM-(IV) AND DIALKYLOSMIUM-(V) PORPHYRINS - CRYSTAL-STRUCTURE OF [OS(TTP)(CH(2)SIME(3))(2)] [H(2)TTP=5,10,15,20-TETRA(P-TOLYL)PORPHYRIN]",
    "Reaction of the [WSe4]2- anion with phosphines: Synthesis and crystal structure of a novel cubane-like cluster [W2Se4(η2-Se2CH2) 2{Cu(PCy3)}2] (Cy=cyclohexyl)"
]

scopus_list = [
    "Synthesis and electrochemistry of dialkylosmium-(IV) and -(V) porphyrins. Crystal structure of [Os(ttp)(CH2SiMe3)2] [H2ttp = 5,10,15,20-tetra(p-tolyl)porphyrin]",
    "Reaction of the [WSe4]2- anion with phosphines:: synthesis and crystal structure of a novel cubane-like cluster [W2Se4(η2-Se2CH2)2{Cu(PCy3)}2] (Cy=cyclohexyl)"
]

matches = []

for scopus_title in scopus_list:
    match = process.extractOne(scopus_title, wos_list)
    matches.append((scopus_title, match[0], match[1]))

# Create a DataFrame from the fuzzy matching results
data = {'Scopus Title': [match[0] for match in matches],
        'WoS Title': [match[1] for match in matches],
        'Score': [match[2] for match in matches]}

df = pd.DataFrame(data)

# Print the DataFrame
df
